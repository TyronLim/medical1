# %%
import seaborn
import matplotlib.pyplot as plt

# 한글설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'    # window 사용자
# matplotlib.rcParams['font.family'] = 'AppleGothic'  # 맥 사용자
matplotlib.rcParams['font.size'] = 13    # window 사용자
matplotlib.rcParams['axes.unicode_minus']=False # 마이너스 표시 해결

# %%
x = [1,2,3]
y = [2,4,8]
x1 = [1,3,4]
y1 = [4,5,6]

# 그래프 그리기
plt.plot(x,y)
plt.plot(x1,y1)

# %%
x = [1,2,3]
plt.plot(x,y)
plt.title('Line graph') # 제목
plt.title('막대그래프')
plt.show()    # 그래프 위의 글자 제거.

# %%
matplotlib.rcParams['axes.unicode_minus']=False # 마이너스 표시 해결
x = [-3,-2,-1,0,1,2,3]
y = [2,4,8,10,5,2,9]
plt.plot(x,y)
