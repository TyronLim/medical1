# %%
import pandas as pd
df = pd.read_csv('../z20_data/chipotle.tsv',sep='\t')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# 메뉴별 주문 수량을 출력하시오.
# len(df.groupby('item_name')['quantity'])      # 50개    .unique
# len(df.groupby('order_id'))      # 1834개    .unique
df['item_name'].value_counts()[:10]
# df.groupby('item_name')['quantity'].count()   똑같음
# df.groupby('item_name')['order_id'].count()
# Out:
# item_name
# Chicken Bowl                    726
# Chicken Burrito                 553
# Chips and Guacamole             479
# Steak Burrito                   368
# Canned Soft Drink               301
# Steak Bowl                      211
# Chips                           211
# Bottled Water                   162
# Chicken Soft Tacos              115
# Chips and Fresh Tomato Salsa    110
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
# 주문 당 평균 계산 금액을 출력하시오.
tot = df['quantity'] * df['item_price'].str.replace('$','').astype(float)
df.groupby('order_id')[tot].mean()
# df.groupby('order_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 3
#       1 # 주문 당 평균 계산 금액을 출력하시오.
#       2 tot = df['quantity'] * df['item_price'].str.replace('$','').astype(float)
# ----> 3 df.groupby('order_id')[tot].mean()
#       4 # df.groupby('order_id')
#
# File c:\Python312\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File c:\Python312\Lib\site-packages\pandas\core\base.py:239, in SelectionMixin.__getitem__(self, key)
# ...
