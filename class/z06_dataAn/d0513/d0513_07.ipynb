# %%
# employees 정보를 가져와서 /  평균 연봉보다 높은 사원을 출력하시오.
import pandas as pd
import oracledb

conn = oracledb.connect(user='ora_user1',password='1111',dsn='localhost:1521/xe')

# %%
sql = 'select * from employees'
df = pd.read_sql_query(sql,conn)
df
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_26504\511640962.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql,conn)
#      EMPLOYEE_ID           EMP_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0            198    Donald OConnell  DOCONNEL  650.507.9833 2007-06-21
# 1            199      Douglas Grant    DGRANT  650.507.9844 2008-01-13
# 2            200    Jennifer Whalen   JWHALEN  515.123.4444 2003-09-17
# 3            201  Michael Hartstein  MHARTSTE  515.123.5555 2004-02-17
# 4            202            Pat Fay      PFAY  603.123.6666 2005-08-17
# ..           ...                ...       ...           ...        ...
# 102          193    Britney Everett  BEVERETT  650.501.2876 2005-03-03
# 103          194      Samuel McCain   SMCCAIN  650.501.3876 2006-07-01
# ...

# %%
sql = 'select * from employees where salary>=(select avg(salary) from employees)'
df = pd.read_sql_query(sql,conn)
df
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_26504\3703514386.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql,conn)
#     EMPLOYEE_ID           EMP_NAME     EMAIL        PHONE_NUMBER  HIRE_DATE  \
# 0           201  Michael Hartstein  MHARTSTE        515.123.5555 2004-02-17
# 1           203       Susan Mavris   SMAVRIS        515.123.7777 2002-06-07
# 2           204       Hermann Baer     HBAER        515.123.8888 2002-06-07
# 3           205    Shelley Higgins  SHIGGINS        515.123.8080 2002-06-07
# 4           206      William Gietz    WGIETZ        515.123.8181 2002-06-07
# 5           100        Steven King     SKING        515.123.4567 2003-06-17
# 6           101      Neena Kochhar  NKOCHHAR        515.123.4568 2005-09-21
# ...

# %%
df[df['SALARY']>=df['SALARY'].mean()]
# df['SALARY'].mean()
# Out:
#     EMPLOYEE_ID           EMP_NAME     EMAIL        PHONE_NUMBER  HIRE_DATE  \
# 0           201  Michael Hartstein  MHARTSTE        515.123.5555 2004-02-17
# 2           204       Hermann Baer     HBAER        515.123.8888 2002-06-07
# 3           205    Shelley Higgins  SHIGGINS        515.123.8080 2002-06-07
# 5           100        Steven King     SKING        515.123.4567 2003-06-17
# 6           101      Neena Kochhar  NKOCHHAR        515.123.4568 2005-09-21
# 7           102        Lex De Haan   LDEHAAN        515.123.4569 2001-01-13
# 9           108    Nancy Greenberg  NGREENBE        515.124.4569 2002-08-17
# 15          114       Den Raphaely  DRAPHEAL        515.127.4561 2002-12-07
# 20          145       John Russell   JRUSSEL  011.44.1344.429268 1998-10-01
# 21          146     Karen Partners  KPARTNER  011.44.1344.467268 1999-01-05
# 22          147  Alberto Errazuriz  AERRAZUR  011.44.1344.429278 1999-03-10
# ...
