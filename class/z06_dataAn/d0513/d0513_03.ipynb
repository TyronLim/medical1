# %%
import pandas as pd
df = pd.read_csv('../z20_data/drinks.csv')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df['continent'].fillna('NN',inplace=True)
df
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_8020\47128143.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['continent'].fillna('NN',inplace=True)
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# ...

# %% [markdown]
# 1. 기초 데이터 파악하기

# %%
len(df[df['continent'].isnull()])
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# 대륙별로 술 소비량
df.groupby('continent')[['beer_servings','spirit_servings','wine_servings']].agg(['min','max','sum','mean'])
# Out:
#           beer_servings                        spirit_servings             \
#                     min  max   sum        mean             min  max   sum
# continent
# AF                    0  376  3258   61.471698               0  152   866
# AS                    0  247  1630   37.045455               0  326  2677
# ET                    1  285  3345  145.434783              68  438  3812
# EU                    0  361  8720  193.777778               0  373  5965
# OC                    0  306  1435   89.687500               0  254   935
# SA                   93  333  2101  175.083333              25  302  1377
#
#                       wine_servings
#                  mean           min  max   sum        mean
# continent
# AF          16.339623             0  233   862   16.264151
# AS          60.840909             0  123   399    9.068182
# ET         165.739130             1  100   564   24.521739
# EU         132.555556             0  370  6400  142.222222
# ...

# %%
df.groupby('continent')[['beer_servings','spirit_servings','wine_servings']].sum()
# Out:
#            beer_servings  spirit_servings  wine_servings
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# ET                  3345             3812            564
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749

# %%
df.groupby('continent')['beer_servings'].value_counts()
# (school['학년'].value_counts(normalize=True).loc['구로고']*100).astype(str)+'%'
# Out:
# continent  beer_servings
# AF         0                3
#            8                3
#            25               3
#            9                2
#            15               2
#                            ..
# SA         167              1
#            193              1
#            213              1
#            245              1
#            333              1
# Name: count, Length: 160, dtype: int64

# %%
# 1. 대륙 AF, 국가, 맥주소비량
# df[df['continent']=='AF'][['country','beer_servings']]
# 대륙 중 AF 국가별 퍼센트 출력
df.groupby('continent').value_counts(normalize=True).loc['AF']
# Out:
# country                   beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# Algeria                   25             0                14             0.7                             0.018868
# Angola                    217            57               45             5.9                             0.018868
# Benin                     34             4                13             1.1                             0.018868
# Botswana                  173            35               35             5.4                             0.018868
# Burkina Faso              25             7                7              4.3                             0.018868
# Burundi                   88             0                0              6.3                             0.018868
# Cabo Verde                144            56               16             4.0                             0.018868
# ...

# %%
df.groupby('continent').value_counts()
# Out:
# continent  country       beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# AF         Algeria       25             0                14             0.7                             1
#            Angola        217            57               45             5.9                             1
#            Benin         34             4                13             1.1                             1
#            Botswana      173            35               35             5.4                             1
#            Burkina Faso  25             7                7              4.3                             1
#                                                                                                        ..
# SA         Paraguay      213            117              74             7.3                             1
#            Peru          163            160              21             6.1                             1
# ...

# %%
# 대륙별 맥주 소비 합계
df.groupby('continent')['beer_servings'].sum()
# Out:
# continent
# AF    3258
# AS    1630
# ET    3345
# EU    8720
# OC    1435
# SA    2101
# Name: beer_servings, dtype: int64

# %%
# 전체 평균보다 맥주 소비량이 높은 대륙을 출력하시오.
a=df.groupby('continent')['beer_servings'].mean()
b=df['beer_servings'].mean()
a[a>b]
a


# if a>b :
#     print(df)
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# NN    145.434783
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
c = df['total_litres_of_pure_alcohol'].mean()
d = df.groupby('continent')['total_litres_of_pure_alcohol'].mean()
d[c>d]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 c = df['total_litres_of_pure_alcohol'].mean()
#       2 d = df.groupby('continent')['total_litres_of_pure_alcohol'].mean()
#       3 d[c>d]
#
# NameError: name 'df' is not defined
