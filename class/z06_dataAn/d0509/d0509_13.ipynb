# %%
import pandas as pd

df = pd.read_excel('../z20_data/20230103_인구.xlsx',skiprows=3,usecols='B,E:Y',index_col='행정기관')
df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         726,460  1,072,653  1,211,077  1,211,949  1,524,378  1,823,908
# 서울특별시      116,614    161,429    185,689    197,425    271,237    390,716
# 부산광역시       41,333     63,912     68,919     67,836     93,245    109,745
# 대구광역시       31,269     49,000     55,029     57,661     74,228     81,001
# 인천광역시       43,664     63,028     70,593     69,580     86,548    108,831
# 광주광역시       21,506     32,852     38,227     39,769     49,779     53,357
# 대전광역시       21,241     31,032     35,302     37,083     48,557     57,944
# 울산광역시       16,646     26,693     29,418     28,366     33,283     39,507
# 세종특별자치시      9,524     13,733     14,079     10,808      9,307     10,329
# ...

# %%
df.shape
df.iloc[2]
# Out:
# 0~4세        41,333
# 5~9세        63,912
# 10~14세      68,919
# 15~19세      67,836
# 20~24세      93,245
# 25~29세     109,745
# 30~34세     103,536
# 35~39세      99,530
# 40~44세     127,544
# 45~49세     121,660
# 50~54세     138,387
# 55~59세     126,702
# 60~64세     143,246
# 65~69세     119,500
# 70~74세      83,807
# 75~79세      55,948
# 80~84세      36,851
# 85~89세      13,453
# 90~94세       3,103
# 95~99세         420
# 100세 이상         72
# Name: 부산광역시  , dtype: object

# %%
df.iloc[0] = df.iloc[0].str.replace(',','').astype(int)
df.iloc[0].sum()
df.iloc[0].mean()
df.loc['전국  ','합계'] = df.iloc[0].sum()
df.loc['전국  ','평균'] = df.iloc[0].mean()
# Out:
# 2330139.8181818184

# %%
df.iloc[1]
df.iloc[1] = df.iloc[1].str.replace(',','').astype(int)
df.iloc[1].sum()
df.iloc[1].mean()
# Out:
# 415249.0

# %%
df[['합계','평균']] = 0
df.loc['전국  ','합계'] = df.iloc[0].sum()
df.loc['전국  ','평균'] = df.iloc[0].mean()
df.loc['서울특별시  ','합계'] = df.iloc[1].sum()
df.loc['서울특별시  ','평균'] = df.iloc[1].mean()
df
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_7812\3520572568.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2228829.3913043477' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc['전국  ','평균'] = df.iloc[0].mean()
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          726460  1072653  1211077  1211949  1524378  1823908  1737714
# 서울특별시       116614   161429   185689   197425   271237   390716   379852
# 부산광역시       41,333   63,912   68,919   67,836   93,245  109,745  103,536
# 대구광역시       31,269   49,000   55,029   57,661   74,228   81,001   76,198
# 인천광역시       43,664   63,028   70,593   69,580   86,548  108,831  107,658
# 광주광역시       21,506   32,852   38,227   39,769   49,779   53,357   45,743
# 대전광역시       21,241   31,032   35,302   37,083   48,557   57,944   51,617
# ...

# %%
df
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          726460  1072653  1211077  1211949  1524378  1823908  1737714
# 서울특별시       116614   161429   185689   197425   271237   390716   379852
# 부산광역시       41,333   63,912   68,919   67,836   93,245  109,745  103,536
# 대구광역시       31,269   49,000   55,029   57,661   74,228   81,001   76,198
# 인천광역시       43,664   63,028   70,593   69,580   86,548  108,831  107,658
# 광주광역시       21,506   32,852   38,227   39,769   49,779   53,357   45,743
# 대전광역시       21,241   31,032   35,302   37,083   48,557   57,944   51,617
# 울산광역시       16,646   26,693   29,418   28,366   33,283   39,507   37,536
# 세종특별자치시      9,524   13,733   14,079   10,808    9,307   10,329   13,538
# 경기도        216,863  313,113  345,546  335,021  411,620  501,356  491,074
# 강원도         20,663   28,244   33,186   35,219   46,654   48,339   43,021
# 충청북도        22,631   32,948   37,693   37,809   47,397   57,064   51,561
# ...

# %%
df[df.columns[-1]]
# Out:
# 행정기관
# 전국           2.228829e+06
# 서울특별시        3.971947e+05
# 부산광역시        0.000000e+00
# 대구광역시        0.000000e+00
# 인천광역시        0.000000e+00
# 광주광역시        0.000000e+00
# 대전광역시        0.000000e+00
# 울산광역시        0.000000e+00
# 세종특별자치시      0.000000e+00
# 경기도          0.000000e+00
# 강원도          0.000000e+00
# 충청북도         0.000000e+00
# 충청남도         0.000000e+00
# 전라북도         0.000000e+00
# 전라남도         0.000000e+00
# 경상북도         0.000000e+00
# 경상남도         0.000000e+00
# 제주특별자치도      0.000000e+00
# Name: 평균, dtype: float64

# %%
o
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_7812\4129307895.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '53491905.391304344' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[[i],[-2]]=df.iloc[i].sum()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[146], line 2
#       1 for i in range(len(df)):
# ----> 2     df.iloc[[i],[-2]]=df.iloc[i].sum()
#       3     df.iloc[[i],[-1]]=df.iloc[i].mean()
#
# File c:\Python312\Lib\site-packages\pandas\core\series.py:6528, in Series.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#    6519 @doc(make_doc("sum", ndim=1))
#    6520 def sum(
#    6521     self,
#    (...)
#    6526     **kwargs,
#    6527 ):
# ...
