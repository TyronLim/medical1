# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus']=False

import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col = '지원번호')
df
# Out:
#        이름   학교  학년    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고   3  197   90   85  100  95  85      Python
# 2번    강태원  구로고   3  184   40   35   50  55  25        Java
# 3번    강호림  구로고   2  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고   1  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고   1  188   15   20   10  35  10         NaN
# 6번    박동현  단지고   3  202   80  100   95  85  80           C
# 7번    박혜정  단지고   2  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고   2  190  100   85   90  95  95          c#

# %%
x = df.head(5)['이름']
y = df.head(5)['국어']
y2 = df.head(5)['영어']
y3 = df.head(5)['수학']

# %%
plt.plot(x,y,label='국어',marker='D')
plt.plot(x,y2,label='영어',marker='o',ls=':')
plt.plot(x,y3,label='수학',marker='s',ls='--')
for i,txt in enumerate(y3):
    plt.text(x[i],y3[i]+1.5,txt,ha='center',color='green')
    
plt.legend(loc='upper center',ncol=3)
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_27020\3384104255.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i],y3[i]+1.5,txt,ha='center',color='green')

# %%
colors=['r','g','b','y','c']
plt.bar(x,y,label='국어',color=colors)
# plt.plot(x,y2,label='영어',marker='o',ls=':')
# plt.bar(x,y3,label='수학')
for i,txt in enumerate(y):
    plt.text(x[i],y[i]+0.5,txt,ha='center',color='green')

plt.xticks(rotation=20)

plt.legend(loc='upper center',ncol=3)
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_27020\2098281625.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i],y[i]+0.5,txt,ha='center',color='green')

# %%
x = df.head(3)['이름']
y = df.head(3)['국어']
y2 = df.head(3)['영어']
y3 = df.head(3)['수학']
bar = plt.bar(x,y,label='국어',width=0.3,alpha=0.5)
# plt.plot(x,y2,label='영어',marker='o',ls=':')
# plt.bar(x,y3,label='수학')
plt.bar[0].set_hatch('/')
plt.bar[1].set_hatch('x')
plt.bar[2].set_hatch('..')
for i,txt in enumerate(y):
    plt.text(x[i],y[i]+0.5,txt,ha='center',color='green')
    
# 패턴

plt.xticks(rotation=20)

plt.legend(loc='upper center',ncol=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 8
#       5 bar = plt.bar(x,y,label='국어',width=0.3,alpha=0.5)
#       6 # plt.plot(x,y2,label='영어',marker='o',ls=':')
#       7 # plt.bar(x,y3,label='수학')
# ----> 8 plt.bar[0].set_hatch('/')
#       9 plt.bar[1].set_hatch('x')
#      10 plt.bar[2].set_hatch('..')
#
# TypeError: 'function' object is not subscriptable
