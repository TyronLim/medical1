# %%
import pandas as pd
df = pd.read_excel('20230103_인구.xlsx',skiprows=3,index_col = '행정기관',usecols='B,E:Y')
df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         726,460  1,072,653  1,211,077  1,211,949  1,524,378  1,823,908
# 서울특별시      116,614    161,429    185,689    197,425    271,237    390,716
# 부산광역시       41,333     63,912     68,919     67,836     93,245    109,745
# 대구광역시       31,269     49,000     55,029     57,661     74,228     81,001
# 인천광역시       43,664     63,028     70,593     69,580     86,548    108,831
# 광주광역시       21,506     32,852     38,227     39,769     49,779     53,357
# 대전광역시       21,241     31,032     35,302     37,083     48,557     57,944
# 울산광역시       16,646     26,693     29,418     28,366     33,283     39,507
# 세종특별자치시      9,524     13,733     14,079     10,808      9,307     10,329
# ...

# %%
df.head(5).to_excel('20230103_인구2.xlsx')

# %%
w_df = pd.read_excel('20230103_인구2.xlsx')
w_df
# Out:
#        행정기관코드     행정기관       남 인구수     연령구간인구수     0~4세       5~9세     10~14세  \
# 0           0     전국    25,631,538  25,631,538  726,460  1,072,653  1,211,077
# 1  1100000000  서울특별시     4,567,739   4,567,739  116,614    161,429    185,689
# 2  2600000000  부산광역시     1,618,749   1,618,749   41,333     63,912     68,919
# 3  2700000000  대구광역시     1,162,217   1,162,217   31,269     49,000     55,029
# 4  2800000000  인천광역시     1,486,300   1,486,300   43,664     63,028     70,593
#
#       15~19세     20~24세     25~29세  ...   55~59세.5   60~64세.5   65~69세.5  \
# 0  1,211,949  1,524,378  1,823,908  ...  2,026,849  2,140,345  1,666,718
# 1    197,425    271,237    390,716  ...    352,974    375,294    313,357
# 2     67,836     93,245    109,745  ...    135,441    160,028    135,481
# 3     57,661     74,228     81,001  ...    101,858    104,716     80,286
# 4     69,580     86,548    108,831  ...    123,617    125,635     90,590
#
# ...

# %%
w_df = pd.read_excel('20230103_인구.xlsx',skiprows=3,index_col='행정기관',usecols='B, AB:AV')
w_df.head()
w_df.columns = df.columns
w_df.columns
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df[0:3]     
df.iloc[0]      #0번째 rows 데이터 가져오기
df.head(3)      
df[df.columns[-1]]

df.iloc[0].str  # str타입으로 변경 
df.iloc[0].str.replace(",","")  # 쉼표 빼기
df.iloc[0].str.replace(",","").astype(int)  # int로 변경
# df.iloc[0].str.replace(",","").astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 6
#       3 df.head(3)
#       4 df[df.columns[-1]]
# ----> 6 df.iloc[0].str  # str타입으로 변경
#       7 df.iloc[0].str.replace(",","")  # 쉼표 빼기
#       8 df.iloc[0].str.replace(",","").astype(int)  # int로 변경
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df.iloc[0]
df.describe
# Out:
# <bound method NDFrame.describe of             0~4세.1   5~9세.1 10~14세.1 15~19세.1 20~24세.1 25~29세.1 30~34세.1  \
# 행정기관
# 전국          691045  1020598  1144645  1134811  1402493  1642682  1579871
# 서울특별시      109,390  154,162  176,096  189,009  304,285  418,972  379,071
# 부산광역시       39,356   60,582   65,329   64,001   88,307  102,363   96,466
# 대구광역시       29,517   47,039   51,645   53,188   65,933   71,873   65,115
# 인천광역시       41,505   59,985   66,881   65,904   80,089   99,535   98,125
# 광주광역시       20,633   31,124   35,819   36,800   46,059   48,645   42,140
# 대전광역시       20,120   29,266   33,099   34,644   45,960   50,861   45,012
# 울산광역시       16,024   25,063   27,185   25,355   25,988   29,820   30,751
# 세종특별자치시      9,323   13,207   13,629   10,886    8,405   10,259   14,210
# 경기도        206,896  298,872  329,545  318,130  378,103  440,729  443,662
# 강원도         19,847   26,739   31,256   32,170   37,089   37,292   36,592
# ...
