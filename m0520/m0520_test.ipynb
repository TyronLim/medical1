# %%
from sklearn import svm,metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus']=False

# %%
# [ 도미 ]
bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0,
33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 700.0, 700.0,
610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]
# [ 빙어 ]
smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
x = [1 for i in range(len(bream_weight))]+[0 for i in range(len(smelt_length))]
y = bream_length + smelt_length
z = bream_weight + smelt_weight
data = [y,z,x]
df = pd.DataFrame(data)
# len(bream_length)
df = df.T
df
# Out:
#        0       1    2
# 0   25.4   242.0  1.0
# 1   26.3   290.0  1.0
# 2   26.5   340.0  1.0
# 3   29.0   363.0  1.0
# 4   29.0   430.0  1.0
# 5   29.7   450.0  1.0
# 6   29.7   500.0  1.0
# 7   30.0   390.0  1.0
# 8   30.0   450.0  1.0
# 9   30.7   500.0  1.0
# 10  31.0   475.0  1.0
# 11  31.0   500.0  1.0
# 12  31.5   500.0  1.0
# 13  32.0   340.0  1.0
# 14  32.0   600.0  1.0
# 15  32.0   600.0  1.0
# 16  33.0   700.0  1.0
# 17  33.0   700.0  1.0
# 18  33.5   610.0  1.0
# 19  33.5   650.0  1.0
# 20  34.0   575.0  1.0
# 21  34.0   685.0  1.0
# 22  34.5   620.0  1.0
# 23  35.0   680.0  1.0
# 24  35.0   700.0  1.0
# 25  35.0   725.0  1.0
# 26  35.0   720.0  1.0
# 27  36.0   714.0  1.0
# 28  36.0   850.0  1.0
# 29  37.0  1000.0  1.0
# 30  38.5   920.0  1.0
# 31  38.5   955.0  1.0
# 32  39.5   925.0  1.0
# 33  41.0   975.0  1.0
# 34  41.0   950.0  1.0
# 35   9.8     6.7  0.0
# 36  10.5     7.5  0.0
# 37  10.6     7.0  0.0
# 38  11.0     9.7  0.0
# 39  11.2     9.8  0.0
# ...

# %% [markdown]
# 수동 랜덤으로 35 / 13 뽑아 나누기

# %%
idx = [i for i in range(len(df))]
random.shuffle(idx)

train_input = df.iloc[idx[0:35],:2]
test_input = df.iloc[idx[35:],:2]
train_target = df.iloc[idx[0:35],2]
test_target = df.iloc[idx[35:],2]

# %%
clf = svm.SVC()
clf.fit(train_input,train_target)

clf.predict(test_input)
clf.score(test_input,test_target)
# Out:
# 1.0
