# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글 설정
matplotlib.rcParams['font.size'] = 10 #글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
data = {
   '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
   '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
   '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
   '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
df = pd.DataFrame(data)
df
# Out:
#           영화  개봉 연도  관객 수    평점
# 0         명량   2014  1761  8.88
# 1       극한직업   2019  1626  9.20
# 2  신과함께-죄와 벌   2017  1441  8.73
# 3       국제시장   2014  1426  9.16
# 4         괴물   2006  1301  8.62
# 5        도둑들   2012  1298  7.64
# 6    7번방의 선물   2013  1281  8.83
# 7         암살   2015  1270  9.10

# %%
# 개봉연도별 평점 선 그래프 출력
# 선 = red, marker 표시
# x축 눈금 표시- 2005,2010,2015,2020/ y축 눈금 범위 - 7, 10

# %%
filt = df.groupby('개봉 연도')['평점'].mean()
filt.index
# Out:
# Index([2006, 2012, 2013, 2014, 2015, 2017, 2019], dtype='int64', name='개봉 연도')

# %%
plt.plot(filt.index,filt.values,color='red',marker='o',mfc='black',mec='black',ls='--')
plt.xticks([2005,2010,2015,2020])
plt.ylim(7,10)
plt.xlabel('개봉 연도')
plt.ylabel('평점')
# Out:
# Text(0, 0.5, '평점')

# %%
# 점수표시
for i,txt in enumerate(filt.values):
    plt.text(filt.index[i],filt.values[i]+0.1,txt,ha='center',color='red')
plt.plot(filt.index,filt.values,color='red',marker='o',mfc='black',mec='black',ls='--')
plt.ylim(7,10)
# plt.xticks(filt.index)
plt.grid(ls='--',alpha=0.4)
plt.show()
